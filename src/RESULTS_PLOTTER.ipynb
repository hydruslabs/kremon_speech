# %%
import os
import pickle
import random
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import torchaudio
import numpy as np
from pydub import AudioSegment, effects
import matplotlib.pyplot as plt

# %%
f = open('19_06_2023_17_39_16.pickle','rb')
log_data = pickle.load(f)
f.close()
limit = 50
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.plot(log_data[1:limit,0],log_data[1:limit,1],'-',label=' Training Loss', color='xkcd:sky blue')
ax1.plot(log_data[1:limit,0],log_data[1:limit,2],'-', label='Testing Loss ',color='tab:blue')
ax1.tick_params(axis='y')
ax1.legend(loc='center right')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis



ax2.set_ylabel('WER', color='tab:red')  # we already handled the x-label with ax1
ax2.plot(log_data[1:limit,0],log_data[1:limit,4], label='WER',color='tab:red')

ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.plot([0.0,0.0],[0.0,1.0],'--',color='white')
ax2.legend(loc='center left')
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Loss Curve - Exp 2')
plt.show()

# %%
f = open('02_10_2023_06_35_47.pickle','rb')
log_data = pickle.load(f)
f.close()
limit = 50
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.plot(log_data[1:limit,0],log_data[1:limit,1],'-',label=' Training Loss', color='xkcd:sky blue')
ax1.plot(log_data[1:limit,0],log_data[1:limit,2],'-', label='Testing Loss ',color='tab:blue')
ax1.tick_params(axis='y')
ax1.legend(loc='center right')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis



ax2.set_ylabel('WER', color='tab:red')  # we already handled the x-label with ax1
ax2.plot(log_data[1:limit,0],log_data[1:limit,4], label='WER',color='tab:red')

ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.plot([0.0,0.0],[0.0,1.0],'--',color='white')
ax2.legend(loc='center left')
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Loss Curve - Exp 2')
plt.show()

# %%
f = open('11_11_2023_21_17_35.pickle','rb')
log_data = pickle.load(f)
f.close()
limit = 100
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.plot(log_data[1:limit,0],log_data[1:limit,1],'-',label=' Training Loss', color='xkcd:sky blue')
ax1.plot(log_data[1:limit,0],log_data[1:limit,2],'-', label='Testing Loss ',color='tab:blue')
ax1.tick_params(axis='y')
ax1.legend(loc='center right')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis



ax2.set_ylabel('WER', color='tab:red')  # we already handled the x-label with ax1
ax2.plot(log_data[1:limit,0],log_data[1:limit,4], label='WER',color='tab:red')

ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.plot([0.0,0.0],[0.0,1.0],'--',color='white')
ax2.legend(loc='center left')
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Loss Curve - Exp 1')
plt.show()

# %%
f  = open('02_12_2023_19_24_07.pickle','rb')
log_data = pickle.load(f)
f.close()
limit = 100
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.plot(log_data[1:limit,0],log_data[1:limit,1],'-',label=' Training Loss', color='xkcd:sky blue')
ax1.plot(log_data[1:limit,0],log_data[1:limit,2],'-', label='Testing Loss ',color='tab:blue')
ax1.tick_params(axis='y')
ax1.legend(loc='center right')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis



ax2.set_ylabel('WER', color='tab:red')  # we already handled the x-label with ax1
ax2.plot(log_data[1:limit,0],log_data[1:limit,4], label='WER',color='tab:red')

ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.plot([0.0,0.0],[0.0,1.0],'--',color='white')
ax2.legend(loc='center left')
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Loss Curve - Exp 3')
plt.show()

# %%
f_1 = open('19_06_2023_17_39_16.pickle','rb')
log_data_1 = pickle.load(f_1)
f_1.close()

f_2 = open('02_10_2023_06_35_47.pickle','rb')
log_data_2 = pickle.load(f_2)
f_2.close()

f_3 = open('11_11_2023_21_17_35.pickle','rb')
log_data_3 = pickle.load(f_3)
f_3.close()

f_4 = open('02_12_2023_19_24_07.pickle','rb')
log_data_4 = pickle.load(f_4)
f_4.close()


limit = 75
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.set_xlabel('Epoch')
ax1.set_ylabel('WER')
ax1.plot(log_data_1[1:limit,0],log_data_1[1:limit,4],'-',label='Exp 1', color='xkcd:steel blue')
ax1.plot(log_data_2[1:limit,0],log_data_2[1:limit,4],'-', label='Exp 2',color='tab:blue')
ax1.plot(log_data_3[1:limit,0],log_data_3[1:limit,4],'-',label='Exp 3', color='xkcd:sky blue')
ax1.plot(log_data_4[1:limit,0],log_data_4[1:limit,4],'-',label='Exp 4', color='tab:red')
ax1.tick_params(axis='y')

ax1.legend(loc='center right')


fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('WER')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 f_1 = open('19_06_2023_17_39_16.pickle','rb')
# ----> 2 log_data_1 = pickle.load(f_1)
#       3 f_1.close()
#       5 f_2 = open('02_10_2023_06_35_47.pickle','rb')
#
# NameError: name 'pickle' is not defined

# %%
f_1 = open('19_06_2023_17_39_16.pickle','rb')
log_data_1 = pickle.load(f_1)
f_1.close()

f_2 = open('02_10_2023_06_35_47.pickle','rb')
log_data_2 = pickle.load(f_2)
f_2.close()

f_3 = open('11_11_2023_21_17_35.pickle','rb')
log_data_3 = pickle.load(f_3)
f_3.close()

f_4 = open('02_12_2023_19_24_07.pickle','rb')
log_data_4 = pickle.load(f_4)
f_4.close()



limit = 100
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.plot(log_data_1[1:limit,0],log_data_1[1:limit,2],'-',label='Exp 1', color='xkcd:steel blue')
ax1.plot(log_data_2[1:limit,0],log_data_2[1:limit,2],'-', label='Exp 2',color='tab:blue')
ax1.plot(log_data_3[1:limit,0],log_data_3[1:limit,2],'-',label='Exp 3', color='xkcd:sky blue')
ax1.plot(log_data_4[1:limit,0],log_data_4[1:limit,2],'-',label='Exp 4', color='tab:red')
ax1.tick_params(axis='y')
ax1.legend(loc='center right')


fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Loss Curve - Test Loss')
plt.show()

# %%
f_1 = open('19_06_2023_17_39_16.pickle','rb')
log_data_1 = pickle.load(f_1)
f_1.close()

f_2 = open('02_10_2023_06_35_47.pickle','rb')
log_data_2 = pickle.load(f_2)
f_2.close()

f_3 = open('11_11_2023_21_17_35.pickle','rb')
log_data_3 = pickle.load(f_3)
f_3.close()

f_4 = open('02_12_2023_19_24_07.pickle','rb')
log_data_4 = pickle.load(f_4)
f_4.close()


limit = 100
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.plot(log_data_1[1:limit,0],log_data_1[1:limit,3],'-',label='Exp 1', color='xkcd:steel blue')
ax1.plot(log_data_2[1:limit,0],log_data_2[1:limit,3],'-', label='Exp 2',color='tab:blue')
ax1.plot(log_data_3[1:limit,0],log_data_3[1:limit,3],'-',label='Exp 3', color='xkcd:sky blue')
ax1.plot(log_data_4[1:limit,0],log_data_4[1:limit,3],'-',label='Exp 4', color='tab:red')
ax1.tick_params(axis='y')
ax1.legend(loc='center right')


fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Loss Curve - Train Loss')
plt.show()

# %%
f_1 = open('19_06_2023_17_39_16.pickle','rb')
log_data_1 = pickle.load(f_1)
f_1.close()

f_2 = open('02_10_2023_06_35_47.pickle','rb')
log_data_2 = pickle.load(f_2)
f_2.close()

f_3 = open('11_11_2023_21_17_35.pickle','rb')
log_data_3 = pickle.load(f_3)
f_3.close()

f_4 = open('02_12_2023_19_24_07.pickle','rb')
log_data_4 = pickle.load(f_4)
f_4.close()


limit = 100
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.set_xlabel('Epoch')
ax1.set_ylabel('WER')
ax1.plot(log_data_1[1:limit,0],log_data_1[1:limit,1],'-',label='Exp 1', color='xkcd:steel blue')
ax1.plot(log_data_2[1:limit,0],log_data_2[1:limit,1],'-', label='Exp 2',color='tab:blue')
ax1.plot(log_data_3[1:limit,0],log_data_3[1:limit,1],'-',label='Exp 3', color='xkcd:sky blue')
ax1.plot(log_data_4[1:limit,0],log_data_4[1:limit,1],'-',label='Exp 4', color='tab:red')
ax1.tick_params(axis='y')

ax1.legend(loc='center right')


fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('WER')
plt.show()
