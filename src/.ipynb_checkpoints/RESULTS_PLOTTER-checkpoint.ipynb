# %%
import os
import pickle
import random
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import torchaudio
import numpy as np
from pydub import AudioSegment, effects
import matplotlib.pyplot as plt

# %%
ls
# Out:
# 15_06_2023_11_12_52.pickle  speechRecognitionScriptV1.py
# 15_06_2023_11_16_45.pickle  speechRecognitionTrainTest.py
# 16_06_2023_05_24_59.pickle  speechRecognitionTrainTestV2.py
# __init__.py                 speechRecognitionTrainTestV3.py
# log.pickle                  Untitled.ipynb
# process.py

# %%
f = open('16_06_2023_05_24_59.pickle','rb')
log_data = pickle.load(f)
f.close()
#plt.ylim([2.775, 3])
plt.plot(log_data[1:,0],log_data[1:,1])
plt.plot(log_data[1:,0],log_data[1:,2])

# %%
plt.plot(log_data[1:,0],log_data[1:,3])
plt.plot(log_data[1:,0],log_data[1:,4])

# %%
log_data[1:,0]
# Out:
# array([2., 3., 4., 5., 6.])
